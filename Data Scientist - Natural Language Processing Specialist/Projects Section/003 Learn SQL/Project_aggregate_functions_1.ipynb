# %% [markdown]
# # Aggregate Functions 1

# %%
import pandas as pd 
import sqlite3


def create_df(cursor: sqlite3.Cursor) -> pd.DataFrame:
    data = cursor.fetchall()
    column_names = [description[0] for description in cursor.description]
    df = pd.DataFrame(data, columns=column_names)
    return df


conn = sqlite3.connect(":memory:")

# %% [markdown]
# #### Prepare Database

# %%
st = """ 
    CREATE TABLE nomnom (
        name TEXT,
        location TEXT,
        category TEXT,
        employees INTEGER,
        raised INTEGER,
        valuation INTEGER,
        founded INTEGER,
        stage TEXT,
        ceo TEXT,
        info TEXT
    );
"""
conn.execute(st)

# %%
df = pd.read_csv("startups.csv", delimiter=";")

name = df["name"].tolist()
location = df["location"].tolist()
category = df["category"].tolist()
employees = df["employees"].tolist()
raised = df["raised"].tolist()
valuation = df["valuation"].tolist()
founded = df["founded"].tolist()
stage = df["stage"].tolist()
ceo = df["ceo"].tolist()
info = df["info"].tolist()

# %%
conn.executemany(
    """INSERT INTO nomnom 
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """,
    zip(name, location, category, employees, raised, valuation, founded, stage, ceo, info)
)

# %% [markdown]
# #### 1.

# %% [markdown]
# Getting started, take a look at the `startups` table:
#
# ```sql
# SELECT *
# FROM startups;
# ```
#
# How many columns are there?

# %%
st = """ 
    SELECT * 
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#                name        location         category  employees       raised  \
# 0        Pied Piper  Silicon Valley  Cloud Computing        6.0    5000000.0
# 1             Hooli  Silicon Valley       Enterprise     9000.0  580000000.0
# 2    Raviga Capital  Silicon Valley  Venture Capital       12.0  300000000.0
# 3            Aviato  Silicon Valley           Travel        3.0     250000.0
# 4          SEE FOOD  Silicon Valley           Mobile        2.0          NaN
# ..              ...             ...              ...        ...          ...
# 65           YoBert        New York        Education       31.0     800000.0
# 66         Trufflez        New York           Mobile       23.0    1000000.0
# 67           Unfade        New York          Fashion        4.0     400000.0
# 68  OrangeYouLonely     Minneapolis           Social       20.0    1200000.0
# 69     WellDeserved   San Francisco       E-commerce        4.0          NaN
#
#        valuation  founded     stage                    ceo  \
# 0   5.000000e+07     2014         A      Richard Hendricks
# 1   4.950000e+10     1997      None           Gavin Bensen
# 2   3.000000e+09     2012      None          Peter Gregory
# 3   2.500000e+06     2006  Acquired         Erlich Bachman
# 4   1.500000e+07     2016  Acquired              Jian-Yang
# ..           ...      ...       ...                    ...
# 65  4.000000e+07     2016  Acquired            Ernie Dzeda
# 66  1.200000e+07     2014      Seed                   None
# 67  5.600000e+06     2016         A           Peggy Grimes
# 68  1.400000e+07     2012      Seed             Gus Dawson
# 69           NaN     2015      Seed  Kasima Tharnpipitchai
#
#                                       info
# 0        A Middle-Out Compression Solution
# 1                    Hooli Is About People
# 2                    Share Only In Success
# 3             Software Aggregation Program
# 4                       The Shazam of Food
# ..                                     ...
# 65    Seasme Street Themed Educational App
# 66     AI Suggests Recipes Based on Photos
# 67                         Everything Hair
# 68                  Dating App for Farmers
# 69  The Premiere Marketplace for Privilege
#
# [70 rows x 10 columns]

# %% [markdown]
# #### 2.

# %% [markdown]
# Calculate the total number of companies in the table.

# %%
st = """ 
    SELECT COUNT(*) AS "Number of startups"
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#    Number of startups
# 0                  70

# %% [markdown]
# #### 3.

# %% [markdown]
# We want to know the total value of all companies in this table.
#
# Calculate this by getting the `SUM()` of the `valuation` column.

# %%
st = """ 
    SELECT SUM(valuation) AS 'Total Valuation'
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#    Total Valuation
# 0     974455790000

# %% [markdown]
# #### 4.

# %% [markdown]
# What is the highest amount raised by a startup?
#
# Return the maximum amount of money `raised`.

# %%
st = """ 
    SELECT MAX(raised) AS "Max Raised"
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#     Max Raised
# 0  11500000000

# %% [markdown]
# #### 5.

# %% [markdown]
# Edit the query so that it returns the maximum amount of money `raised`, during ‘Seed’ stage.

# %%
st = """ 
    SELECT MAX(raised) AS "Max Raised"
    FROM nomnom
    WHERE stage = 'Seed';
"""

create_df(conn.execute(st))
# Out:
#    Max Raised
# 0     1800000

# %% [markdown]
# #### 6.

# %% [markdown]
# In what year was the oldest company on the list founded?

# %%
st = """ 
    SELECT MIN(founded) AS "Oldest Startup Founded"
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#    Oldest Startup Founded
# 0                    1994

# %% [markdown]
# #### 7.

# %% [markdown]
# Return the average `valuation`.

# %%
st = """ 
    SELECT AVG(valuation) AS "Average Valuation"
    FROM nomnom;
"""

create_df(conn.execute(st))
# Out:
#    Average Valuation
# 0       1.597469e+10

# %% [markdown]
# #### 8.

# %% [markdown]
# Return the average `valuation`, in each `category`.

# %%
st = """ 
    SELECT category, AVG(valuation) AS "Average Valuation"
    FROM nomnom
    GROUP BY category;
"""

create_df(conn.execute(st))
# Out:
#               category  Average Valuation
# 0                 None       4.290000e+06
# 1           Algorithms       7.600000e+06
# 2    Augmented Reality       8.000000e+09
# 3   Big Data Analytics       1.500000e+07
# 4      Cloud Computing       9.500000e+07
# 5     Customer Service       6.400000e+08
# 6       Data Analytics                NaN
# 7           E-commerce       6.025000e+07
# 8            Education       2.023800e+09
# 9           Enterprise       3.850833e+10
# 10             Fashion       3.200000e+06
# 11             Fitness       6.750000e+07
# 12            Gambling       3.220000e+08
# 13               Games       1.600000e+06
# 14         Health Care       3.804900e+11
# 15           Logistics       7.000000e+07
# 16              Mobile       9.600000e+06
# 17      Nanotechnology       1.500000e+08
# 18         Real Estate       2.000000e+10
# 19                SaaS       4.010000e+08
# 20            Security       6.333333e+09
# 21              Social       8.242583e+07
# 22          Technology       3.100000e+09
# 23              Travel       1.250125e+10
# 24     Venture Capital       3.000000e+09
# 25     Video Streaming                NaN
# 26     Virtual Reality       2.150000e+06

# %% [markdown]
# #### 9.

# %% [markdown]
# Return the average `valuation`, in each `category`.
#
# Round the averages to two decimal places.

# %%
st = """ 
    SELECT category, ROUND(AVG(valuation), 2) AS "Average Valuation"
    FROM nomnom
    GROUP BY category;
"""

create_df(conn.execute(st))
# Out:
#               category  Average Valuation
# 0                 None       4.290000e+06
# 1           Algorithms       7.600000e+06
# 2    Augmented Reality       8.000000e+09
# 3   Big Data Analytics       1.500000e+07
# 4      Cloud Computing       9.500000e+07
# 5     Customer Service       6.400000e+08
# 6       Data Analytics                NaN
# 7           E-commerce       6.025000e+07
# 8            Education       2.023800e+09
# 9           Enterprise       3.850833e+10
# 10             Fashion       3.200000e+06
# 11             Fitness       6.750000e+07
# 12            Gambling       3.220000e+08
# 13               Games       1.600000e+06
# 14         Health Care       3.804900e+11
# 15           Logistics       7.000000e+07
# 16              Mobile       9.600000e+06
# 17      Nanotechnology       1.500000e+08
# 18         Real Estate       2.000000e+10
# 19                SaaS       4.010000e+08
# 20            Security       6.333333e+09
# 21              Social       8.242583e+07
# 22          Technology       3.100000e+09
# 23              Travel       1.250125e+10
# 24     Venture Capital       3.000000e+09
# 25     Video Streaming                NaN
# 26     Virtual Reality       2.150000e+06

# %% [markdown]
# #### 10.

# %% [markdown]
# Return the average `valuation`, in each `category`.
#
# Round the averages to two decimal places.
#
# Lastly, order the list from highest averages to lowest.

# %%
st = """ 
    SELECT category, ROUND(AVG(valuation), 2) AS "Average Valuation"
    FROM nomnom
    GROUP BY 1
    ORDER BY 2 DESC;
"""

create_df(conn.execute(st))
# Out:
#               category  Average Valuation
# 0          Health Care       3.804900e+11
# 1           Enterprise       3.850833e+10
# 2          Real Estate       2.000000e+10
# 3               Travel       1.250125e+10
# 4    Augmented Reality       8.000000e+09
# 5             Security       6.333333e+09
# 6           Technology       3.100000e+09
# 7      Venture Capital       3.000000e+09
# 8            Education       2.023800e+09
# 9     Customer Service       6.400000e+08
# 10                SaaS       4.010000e+08
# 11            Gambling       3.220000e+08
# 12      Nanotechnology       1.500000e+08
# 13     Cloud Computing       9.500000e+07
# 14              Social       8.242583e+07
# 15           Logistics       7.000000e+07
# 16             Fitness       6.750000e+07
# 17          E-commerce       6.025000e+07
# 18  Big Data Analytics       1.500000e+07
# 19              Mobile       9.600000e+06
# 20          Algorithms       7.600000e+06
# 21                None       4.290000e+06
# 22             Fashion       3.200000e+06
# 23     Virtual Reality       2.150000e+06
# 24               Games       1.600000e+06
# 25     Video Streaming                NaN
# 26      Data Analytics                NaN

# %% [markdown]
# #### 11.

# %% [markdown]
# First, return the name of each `category` with the total number of companies that belong to it.

# %%
st = """ 
    SELECT category, COUNT(*) AS "Number of Startups"
    FROM nomnom
    GROUP BY 1;
"""

create_df(conn.execute(st))
# Out:
#               category  Number of Startups
# 0                 None                   3
# 1           Algorithms                   1
# 2    Augmented Reality                   1
# 3   Big Data Analytics                   1
# 4      Cloud Computing                   2
# 5     Customer Service                   1
# 6       Data Analytics                   1
# 7           E-commerce                   3
# 8            Education                   5
# 9           Enterprise                   3
# 10             Fashion                   2
# 11             Fitness                   3
# 12            Gambling                   1
# 13               Games                   2
# 14         Health Care                   2
# 15           Logistics                   1
# 16              Mobile                  10
# 17      Nanotechnology                   1
# 18         Real Estate                   1
# 19                SaaS                   2
# 20            Security                   3
# 21              Social                  12
# 22          Technology                   3
# 23              Travel                   2
# 24     Venture Capital                   1
# 25     Video Streaming                   1
# 26     Virtual Reality                   2

# %% [markdown]
# #### 12.

# %% [markdown]
# Next, filter the result to only include categories that have more than three companies in them.
#
# What are the most competitive markets?

# %%
st = """ 
    SELECT category, COUNT(*) AS "Number of Startups"
    FROM nomnom
    GROUP BY 1
    HAVING COUNT(*) > 3;
"""

create_df(conn.execute(st))
# Out:
#     category  Number of Startups
# 0  Education                   5
# 1     Mobile                  10
# 2     Social                  12

# %% [markdown]
# #### 13.

# %% [markdown]
# What is the average size of a startup in each `location`?

# %%
st = """ 
    SELECT location, AVG(employees) AS "Average Employees"
    FROM nomnom
    GROUP BY 1;
"""

create_df(conn.execute(st))
# Out:
#            location  Average Employees
# 0           Atlanta           3.000000
# 1           Boulder           3.000000
# 2          Brooklyn         502.666667
# 3           Chicago          12.000000
# 4          Columbus           2.000000
# 5            Denver          12.000000
# 6   Fort Lauderdale         500.000000
# 7            Irvine           2.000000
# 8       Long Island           5.000000
# 9       Los Angeles           6.833333
# 10      Minneapolis          20.000000
# 11        New Delhi         250.000000
# 12         New York         702.750000
# 13            Omaha          65.000000
# 14        Palo Alto         125.833333
# 15            Paris          30.000000
# 16    San Francisco        1920.400000
# 17         Savannah           6.000000
# 18         Scranton           6.000000
# 19          Seattle           9.666667
# 20   Silicon Valley        1804.600000
# 21   Virginia Beach          15.000000
# 22    Washington DC           8.000000

# %% [markdown]
# #### 14.

# %% [markdown]
# What is the average size of a startup in each `location`, with average sizes above 500?

# %%
st = """ 
    SELECT location, AVG(employees) AS "Average Employees"
    FROM nomnom
    GROUP BY 1
    HAVING AVG(employees) > 500;
"""

create_df(conn.execute(st))
# Out:
#          location  Average Employees
# 0        Brooklyn         502.666667
# 1        New York         702.750000
# 2   San Francisco        1920.400000
# 3  Silicon Valley        1804.600000
