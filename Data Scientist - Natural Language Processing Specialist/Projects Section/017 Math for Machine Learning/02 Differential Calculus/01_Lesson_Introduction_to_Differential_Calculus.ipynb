# %% [markdown]
# # Introduction to Differential Calculus

# %%
import numpy as np
from math import sin
import matplotlib.pyplot as plt

# %% [markdown]
# ## 8. Calculating Derivatives in Python

# %% [markdown]
# **Task 1**
# - We have code that defines and plots the following function:
# $$ f(x) = sin(x) $$
# - `sin_x` contains the *x*-values, while `sin_y` contains the *y*-values.
# - Define a variable `sin_deriv` that calculates the derivative of *f(x) = sin(x)*.
#
# <br>
#
# **Task 2**
# - Uncomment the following line of code to plot `sin_deriv`:
#     ```python
#     #plt.plot(sin_x, sin_deriv)
#     ```
# - What does the new plot look like?
#
# <br>
#
# **Task 3**
# - Let’s play around with the `dx` variable.
# - Change the value of `dx` from `0.01` to `1`.
# - What do you notice about the graphs after you hit run?
# - Does the accuracy of your calculation appear to increase or decrease?

# %%
# our change in x value
dx = 0.01
def f(x):
    return sin(x) 
sin_x = [x for x in np.arange(0,20,dx)] # 0 to 20 in increments of 0.01
sin_y = [f(x) for x in np.arange(0,20,dx)] # sin(x) for each x in 0 to 20 in increments of 0.01
print(sin_y)

plt.plot(sin_x, sin_y)
#plt.plot(sin_x, sin_deriv)
plt.show()
# Out:
# [0.0, 0.009999833334166664, 0.01999866669333308, 0.02999550020249566, 0.03998933418663416, 0.04997916927067833, 0.059964006479444595, 0.06994284733753277, 0.0799146939691727, 0.08987854919801104, 0.09983341664682815, 0.10977830083717481, 0.11971220728891936, 0.12963414261969486, 0.1395431146442365, 0.14943813247359922, 0.15931820661424598, 0.16918234906699603, 0.17902957342582418, 0.18885889497650057, 0.19866933079506122, 0.20845989984609956, 0.21822962308086932, 0.2279775235351884, 0.23770262642713458, 0.24740395925452294, 0.2570805518921551, 0.26673143668883115, 0.27635564856411376, 0.28595222510483553, 0.29552020666133955, 0.3050586364434435, 0.31456656061611776, 0.32404302839486837, 0.3334870921408144, 0.3428978074554514, 0.35227423327508994, 0.361615431964962, 0.3709204694129827, 0.3801884151231614, 0.3894183423086505, 0.39860932798442295, 0.40776045305957015, 0.41687080242921076, 0.4259394650659996, 0.43496553411123023, 0.4439481069655198, 0.45288628537906833, 0.461779175541482
# ...

# %%
# Task 1
sin_deriv = np.gradient(sin_y, dx)
print(sin_deriv)

# Task 2
plt.plot(sin_x, sin_deriv)
plt.show()
# Out:
# [0.99998333 0.99993333 0.99978334 ... 0.43527543 0.42625103 0.42172806]

# %%
# Task 3
dx = 1
def f(x):
    return sin(x) 
sin_x = [x for x in np.arange(0,20,dx)] # 0 to 20 in increments of 0.01
sin_y = [f(x) for x in np.arange(0,20,dx)] # sin(x) for each x in 0 to 20 in increments of 0.01
sin_deriv = np.gradient(sin_y, dx)

plt.plot(sin_x, sin_y)
plt.plot(sin_x, sin_deriv)
plt.show()
