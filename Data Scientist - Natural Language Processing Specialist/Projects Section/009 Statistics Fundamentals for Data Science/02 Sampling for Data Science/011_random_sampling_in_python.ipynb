# %% [markdown]
# # Random Samling in Python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Investigate the Population

# %% [markdown]
# Loading the CSV file

# %%
population = pd.read_csv("salmon_population.csv")
population.head()
# Out:
#    Salmon_Weight
# 0       3.275205
# 1      84.000717
# 2      17.127989
# 3      68.628082
# 4      51.100461

# %% [markdown]
# Convert into numpy array

# %%
population = np.array(population.Salmon_Weight)
population[:5]
# Out:
# array([ 3.27520533, 84.00071734, 17.12798857, 68.62808197, 51.10046104])

# %% [markdown]
# Calculate mean of the `population`

# %%
pop_mean = round(np.mean(population), 3)
pop_mean
# Out:
# np.float64(60.708)

# %% [markdown]
# Plotting the `population` distribution

# %%
sns.histplot(population, stat='density')
plt.axvline(pop_mean,color='r',linestyle='dashed')
plt.title(f"Population Mean: {pop_mean}")
plt.xlabel("Weight (lbs)")
plt.show()

# %% [markdown]
# ### Investigate the Sample

# %%
sample_size = 10
sample = np.random.choice(population, sample_size, replace=False)
sample_mean = round(np.mean(sample), 3)

sns.histplot(sample, stat='density')
plt.axvline(sample_mean,color='r',linestyle='dashed')
plt.title(F"Sample Mean: {sample_mean}")
plt.xlabel("Weight (lbs)")
plt.show()

# %%
def create_hists(sample_sizes, population):
    n_sample_sizes = len(sample_sizes)
    fig_size = 5
    fig, axes = plt.subplots(1, n_sample_sizes, figsize=(fig_size*n_sample_sizes, fig_size))
    for i, sample_size in enumerate(sample_sizes):
        sample = np.random.choice(population, sample_size, replace=False)
        sample_mean = round(np.mean(sample), 3)
        sns.histplot(sample, stat='density', ax=axes[i])
        axes[i].axvline(sample_mean, color='r', linestyle='dashed')
        axes[i].set_title(F"Sample Size: {sample_size}\nSample Mean: {sample_mean}")
        axes[i].set_xlabel("Weight (lbs)")
    plt.tight_layout()
    plt.show()

# %%
create_hists([10, 50, 100, 500, 1000], population)
