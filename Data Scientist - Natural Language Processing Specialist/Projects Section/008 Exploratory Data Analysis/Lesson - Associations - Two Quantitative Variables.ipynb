# %% [markdown]
# # Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import pearsonr

# %% [markdown]
# - As a final exercise, a new dataset named `penguins` has been uploaded.
# - This dataset contains various measurements for a sample of penguins.
# - To practice the skills learned in this lesson, here are some things to try

# %% [markdown]
# - Inspect the first few rows of data.

# %%
df = pd.read_csv('penguins.csv')
df.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie            39.1           18.7              181.0       3750.0
# 1  Adelie            39.5           17.4              186.0       3800.0
# 2  Adelie            40.3           18.0              195.0       3250.0
# 3  Adelie            36.7           19.3              193.0       3450.0
# 4  Adelie            39.3           20.6              190.0       3650.0
#
#       sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %% [markdown]
# - Create a scatter plot of flipper length (`flipper_length_mm`) and body mass (`body_mass_g`).

# %%
plt.scatter(x=df.flipper_length_mm, y=df.body_mass_g)
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.title('Flipper Length vs Body Mass')
plt.show()

# %% [markdown]
# - Inspect your plot. What is the relationship between these variables?

# %%
# Strong relationsship, should be near 1

# %% [markdown]
# - Calculate the covariance for these two variables.

# %%
cov = np.cov(df.flipper_length_mm, df.body_mass_g)
cov, cov[0, 1]
# Out:
# (array([[1.96441677e+02, 9.85219165e+03],
#         [9.85219165e+03, 6.48372488e+05]]),
#  np.float64(9852.191649480807))

# %% [markdown]
# - Calculate the correlation for these two variables. Does this number make sense given the plot you created?

# %%
corr, p = pearsonr(df.flipper_length_mm, df.body_mass_g)
corr
# Out:
# np.float64(0.8729788985653614)

# %%
# cov(X, Y) / (std(X) * std(Y))

corr_2 = cov[0, 1] / (np.std(df.flipper_length_mm) * np.std(df.body_mass_g))
corr_2
# Out:
# np.float64(0.8756083530791123)
